# %% [markdown]
# <a href="https://colab.research.google.com/github/Anurag-2601/AI-lab/blob/main/FinancialData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded)
# Out:
#      <input type="file" id="files-d1c10189-a512-40c5-985f-605e3aa5b330" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1c10189-a512-40c5-985f-605e3aa5b330">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from io import BytesIO

df = pd.read_csv(BytesIO(uploaded['XYZCorp_LendingData - Copy (1).csv']),nrows=73)

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... Unnamed: 236 Unnamed: 237  \
# 0     10.65       162.87     B        B2  ...          NaN          NaN
# 1     15.27        59.83     C        C4  ...          NaN          NaN
# 2     15.96        84.33     C        C5  ...          NaN          NaN
# 3     13.49       339.31     C        C1  ...          NaN          NaN
# 4     12.69        67.79     B        B5  ...          NaN          NaN
#
#   Unnamed: 238  Unnamed: 239 Unnamed: 240 Unnamed: 241 Unnamed: 242  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Columns: 246 entries, id to Unnamed: 245
# dtypes: float64(222), int64(4), object(20)
# memory usage: 140.4+ KB

# %%
df.dtypes
# Out:
# id                   int64
# member_id            int64
# loan_amnt            int64
# funded_amnt          int64
# funded_amnt_inv    float64
#                     ...
# Unnamed: 241       float64
# Unnamed: 242       float64
# Unnamed: 243       float64
# Unnamed: 244       float64
# Unnamed: 245       float64
# Length: 246, dtype: object

# %%
df.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  8.559460e+05  8.559460e+05  855946.000000  855946.000000
# mean   3.224159e+07  3.476362e+07   14745.697392   14732.504007
# std    2.271939e+07  2.399383e+07    8425.370606    8419.502316
# min    5.473400e+04  7.069900e+04     500.000000     500.000000
# 25%    9.068214e+06  1.079301e+07    8000.000000    8000.000000
# 50%    3.431366e+07  3.697543e+07   13000.000000   13000.000000
# 75%    5.446321e+07  5.803572e+07   20000.000000   20000.000000
# max    6.861687e+07  7.351969e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    855946.000000  855946.000000  855946.000000  8.402250e+05
# mean      14700.363661      13.192374     436.240909  7.470292e+04
# std        8425.714203       4.368399     243.727750  6.418838e+04
# min           0.000000       5.320000      15.690000  0.000000e+00
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# member_id               0
# loan_amnt               0
# funded_amnt             0
# funded_amnt_inv         0
#                     ...
# Unnamed: 241       855945
# Unnamed: 242       855945
# Unnamed: 243       855945
# Unnamed: 244       855945
# Unnamed: 245       855945
# Length: 246, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'pymnt_plan',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
# ...

# %%
# Drop columns with more than 70 missing values
df_clear = df.dropna(axis=1, thresh=len(df) - 70)

# %%
df_clear.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  7.300000e+01  7.300000e+01     73.000000     73.000000
# mean   1.067706e+06  1.299198e+06   9886.301370   9618.835616
# std    7.583626e+03  1.081064e+04   5878.961491   5665.322728
# min    1.032111e+06  1.261745e+06   1000.000000   1000.000000
# 25%    1.068945e+06  1.298717e+06   5375.000000   5375.000000
# 50%    1.069346e+06  1.303778e+06  10000.000000   9200.000000
# 75%    1.069710e+06  1.304634e+06  12500.000000  12000.000000
# max    1.077501e+06  1.314167e+06  31825.000000  31825.000000
#
#        funded_amnt_inv   int_rate  installment     annual_inc        dti  \
# count        73.000000  73.000000    73.000000      70.000000  51.000000
# mean       9510.851522  12.750685   293.511918   53589.074143  13.769804
# std        5590.834730   3.825386   175.253251   24637.333076   6.413935
# min        1000.000000   6.030000    35.310000   12252.000000   1.000000
# ...

# %%
df_clear.dtypes
# Out:
# id                              int64
# member_id                       int64
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                      float64
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                        object
# pymnt_plan                     object
# desc                           object
# purpose                        object
# title                          object
# zip_code                       object
# addr_state                     object
# dti                           float64
# delinq_2yrs                   float64
# earliest_cr_line               object
# ...

# %%
dfc.isnull().sum()
# Out:
# id                             0
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                      6
# emp_length                     3
# home_ownership                 3
# annual_inc                     3
# verification_status            3
# issue_d                        3
# pymnt_plan                     3
# desc                          26
# purpose                       22
# title                         22
# zip_code                      22
# addr_state                    22
# dti                           22
# delinq_2yrs                   22
# earliest_cr_line              22
# inq_last_6mths                22
# mths_since_last_delinq        64
# open_acc                      22
# ...

# %%
dfc = df_clear.copy()

# %%
dfc['emp_title'] = dfc['emp_title'].fillna('Unknown')
dfc['emp_length'] = dfc['emp_length'].fillna(dfc['emp_length'].mode()[0])
dfc['home_ownership'] = dfc['home_ownership'].fillna(dfc['home_ownership'].mode()[0])
dfc['annual_inc'] = dfc['annual_inc'].fillna(dfc['annual_inc'].median())
dfc['verification_status'] = dfc['verification_status'].fillna(dfc['verification_status'].mode()[0])
dfc['issue_d'] = dfc['issue_d'].fillna(dfc['issue_d'].mode()[0])
# or
# dfc['issue_d'] = dfc['issue_d'].fillna('Unknown')
dfc['pymnt_plan'] = dfc['pymnt_plan'].fillna('n')

# %%
# Option 1: drop (if not doing NLP)
#dfc = dfc.drop(columns=['desc'])

 #Option 2: fill with text
dfc['desc'] = dfc['desc'].fillna('No description')
dfc['purpose'] = dfc['purpose'].fillna(dfc['purpose'].mode()[0])
dfc['title'] = dfc['title'].fillna('Unknown')
# or
# dfc = dfc.drop(columns=['title'])
dfc['zip_code'] = dfc['zip_code'].fillna('Unknown')
dfc['addr_state'] = dfc['addr_state'].fillna(dfc['addr_state'].mode()[0])
dfc['dti'] = dfc['dti'].fillna(dfc['dti'].median())
dfc['delinq_2yrs'] = dfc['delinq_2yrs'].fillna(0)
dfc['earliest_cr_line'] = dfc['earliest_cr_line'].fillna(dfc['earliest_cr_line'].mode()[0])
dfc['inq_last_6mths'] = dfc['inq_last_6mths'].fillna(0)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /tmp/ipython-input-1452243455.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfc['dti'] = dfc['dti'].fillna(dfc['dti'].median())

# %%
dfc['mths_since_last_delinq'] = dfc['mths_since_last_delinq'].fillna(0)
dfc['open_acc'] = dfc['open_acc'].fillna(dfc['open_acc'].median())
dfc['pub_rec'] = dfc['pub_rec'].fillna(0)
dfc['revol_bal'] = dfc['revol_bal'].fillna(dfc['revol_bal'].median())
dfc['revol_util'] = dfc['revol_util'].fillna(dfc['revol_util'].median())
dfc['total_acc'] = dfc['total_acc'].fillna(dfc['total_acc'].median())
dfc['initial_list_status'] = dfc['initial_list_status'].fillna(dfc['initial_list_status'].mode()[0])
dfc['out_prncp'] = dfc['out_prncp'].fillna(0)
dfc['out_prncp_inv'] = dfc['out_prncp_inv'].fillna(0)
dfc['last_pymnt_d'] = dfc['last_pymnt_d'].fillna('Unknown')
dfc['last_credit_pull_d'] = dfc['last_credit_pull_d'].fillna('Unknown')
dfc['collections_12_mths_ex_med'] = dfc['collections_12_mths_ex_med'].fillna(0)
dfc['policy_code'] = dfc['policy_code'].fillna(dfc['policy_code'].mode()[0])
dfc['application_type'] = dfc['application_type'].fillna(dfc['application_type'].mode()[0])
dfc['acc_now_delinq'] = dfc['acc_now_delinq'].fillna(0)
dfc = dfc.dropna(subset=['default_ind'])

# %%
dfc.isnull().sum()
# Out:
# id                             0
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                      0
# emp_length                     0
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# issue_d                        0
# pymnt_plan                     0
# desc                           0
# purpose                        0
# title                          0
# zip_code                       0
# addr_state                     0
# dti                           51
# delinq_2yrs                    0
# earliest_cr_line               0
# inq_last_6mths                 0
# mths_since_last_delinq         0
# open_acc                       0
# ...

# %%
cols_to_drop = [
    'id', 'member_id', 'funded_amnt', 'funded_amnt_inv',
    'emp_title', 'title', 'zip_code', 'desc',
    'issue_d', 'earliest_cr_line', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d',
    'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
    'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
    'collection_recovery_fee', 'last_pymnt_amnt',
    'policy_code', 'annual_inc_joint', 'dti_joint', 'verification_status_joint',
    'pymnt_plan', 'dti'
]

df_f = dfc.drop(columns=cols_to_drop, errors='ignore')

# %%
df_f.dtypes
# Out:
# loan_amnt                       int64
# term                           object
# int_rate                      float64
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# purpose                        object
# addr_state                     object
# delinq_2yrs                   float64
# inq_last_6mths                float64
# mths_since_last_delinq        float64
# open_acc                      float64
# pub_rec                       float64
# revol_bal                     float64
# revol_util                    float64
# total_acc                     float64
# initial_list_status            object
# collections_12_mths_ex_med    float64
# application_type               object
# acc_now_delinq                float64
# default_ind                   float64
# ...

# %%
df_encoded = pd.get_dummies(df_f, columns=['grade','term','sub_grade', 'emp_length', 'home_ownership', 'verification_status', 'purpose', 'addr_state', 'initial_list_status', 'application_type'], drop_first=True)
display(df_encoded.corr())
# Out:
#                loan_amnt  int_rate  installment  annual_inc  delinq_2yrs  \
# loan_amnt       1.000000  0.002594     0.913607    0.200792    -0.188104
# int_rate        0.002594  1.000000    -0.105799   -0.294103     0.096345
# installment     0.913607 -0.105799     1.000000    0.306805    -0.203404
# annual_inc      0.200792 -0.294103     0.306805    1.000000     0.160285
# delinq_2yrs    -0.188104  0.096345    -0.203404    0.160285     1.000000
# ...                  ...       ...          ...         ...          ...
# addr_state_SC   0.015820 -0.181591     0.026216    0.083457    -0.032588
# addr_state_TX  -0.058202  0.149624    -0.020876   -0.112478    -0.032588
# addr_state_UT  -0.090772 -0.031364    -0.075620    0.172994     0.521400
# addr_state_VA  -0.023928  0.129949     0.031898   -0.056730    -0.046554
# addr_state_WA   0.353362  0.261937     0.287039   -0.017321    -0.032588
#
#                inq_last_6mths  mths_since_last_delinq  open_acc   pub_rec  \
# ...

# %%
X = df_encoded.drop('default_ind', axis=1)
y = df_encoded['default_ind']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# Split (normally you'd use a bigger dataset)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns
numerical_cols = X_train.select_dtypes(include=['float64', 'int64']).columns

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform on training data, transform on test data
X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])

# %% [markdown]
# the above snippet is ipmortant

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89        14
#          1.0       0.50      0.67      0.57         3
#
#     accuracy                           0.82        17
#    macro avg       0.71      0.76      0.73        17
# weighted avg       0.85      0.82      0.83        17

# %%
from sklearn.metrics import accuracy_score
y_pred = lr.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Model Accuracy: 82.35 %

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp_cm=ConfusionMatrixDisplay(confusion_matrix=cm)
disp_cm.plot()
plt.show()
